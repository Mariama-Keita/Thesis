# %%
import importlib
import parsing
importlib.reload(parsing)
from parsing import build_tables, verify, write_tables
import pandas as pd

# %%
clean = pd.read_csv("/home/sheikh/Projects/Thesis/data/medium_clean.csv")

# %%
tables = parsing.build_tables(clean)
parsing.verify(tables, clean)
# Out:
# === PARSING VERIFICATION ===
#
#   mediums                            1165
#   mediums_unnamed                    4
#   components_unique                  1327
#   instructions                       2305
#   compositions                       12931
#   mono_lines_in_source               12931
#   mono_unreadable                    0
#   compositions_unmapped_component    0
#   mediums_with_no_components         143
#
#   medium types
#     standard       954
#     reference      149
#     solution       60
#     unique         2
#
#   instruction kinds
#     instruction    1743
#     sub_recipe     346
#     solution       130
#     needs_review   78
#     comment        8
#
#   reference types
#     None           11470
#     sub_recipe     997
#     internal       347
#     unresolved     43
#     external       42
#     whole          32

# %%
parsing.write_tables(tables, "/home/sheikh/Projects/Thesis/data")
